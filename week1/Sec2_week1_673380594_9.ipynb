# %% [markdown]
# #1.สร้างเซลล์ใหม่

# %% [markdown]
# Week 1 673380594-9 นางสาวพรีมภัทร ภาวัฒนวคุณ

# %%
print("Hello, Python Course!")
# Out:
# Hello, Python Course!

# %% [markdown]
# #2.ประกาศตัวแปลและแสดงผล

# %%
Name = "Preempaht"
Age = 23
GPA = 5.00
Favorite_Color = "Black"
Student = True

print("Name =",Name  ,type(Name))
print("Age = ",Age ,type(Age))
print("GPA = ",GPA,type(GPA))
print("Favorite_Color = ",Favorite_Color,type(Favorite_Color))
print("Student = ",Student,type(Student))
# Out:
# Name = Preempaht <class 'str'>
# Age =  23 <class 'int'>
# GPA =  5.0 <class 'float'>
# Favorite_Color =  Black <class 'str'>
# Student =  True <class 'bool'>

# %% [markdown]
# #3.ประกาศตัวแปรและคำนวณ

# %%
num1 = 60
num2 = 9
sum1 = num1 + num2
print("Sum = ",sum1)
# Out:
# Sum =  69

# %%
Firstname = "Preemphat"
Lastname = "Pawatnavakun"
Fullname = Firstname + " " + Lastname
print(f"Hello,{Fullname}")
# Out:
# Hello,Preemphat Pawatnavakun

# %%
num = input("What your favorite number : ")
print("type of A is : ", type(num))
num = int(num)
result = num + 7
print(num," + 7 = ", result)
# Out:
# What your favorite number : 69
# type of A is :  <class 'str'>
# 69  + 7 =  76

# %% [markdown]
# Python Scripting สามารถนำไปใช้ทำอะไรได้บ้าง?
#
# ตอบ : Python Scripting สามารถนำไปใช้ได้หลายด้าน เช่น
# เขียนโปรแกรมอัตโนมัติ (Automation)
# วิเคราะห์ข้อมูล (Data Analysis)
# พัฒนาเว็บไซต์ (Web Development)
# พัฒนา AI และ Machine Learning
# สร้างเกมและแอปพลิเคชัน
# จัดการไฟล์และฐานข้อมูล

# %%
# Puzzler 1
x = 10
y = 3.5
z = x + y
print(z)
print(type(z))
# Out:
# 13.5
# <class 'float'>

# %% [markdown]
# และทำไม type(z) จึงเป็น float?
#
# ตอบ : เพราะว่า x เป็นชนิด int และ y เป็นชนิด float เมื่อบวกกัน Python จะเปลี่ยนผลลัพธ์ให้เป็นชนิด float อัตโนมัติ เพื่อรักษาค่าทศนิยมไว้

# %%
# Puzzler 2
name = "Alice"
age = "30" # Note: This is a string
message = name + " is " + age + " years old."
print(message)
print(type(age))
# Out:
# Alice is 30 years old.
# <class 'str'>

# %% [markdown]
# ทำไม type(age) จึงเป็น str?
#
# ตอบ : เนื่องจาก "30" อยู่ภายในเครื่องหมาย " " จึงถือเป็นข้อความ (String) ไม่ใช่ตัวเลข ดังนั้น type(age) จึงเป็น str

# %%
# Puzzler 3
is_sunny = True
is_raining = False
print(is_sunny and is_raining)
print(type(is_sunny))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# ทำไม type(is_sunny) จึงเป็น bool?
#
# ตอบ : เพราะ True และ False เป็นค่าความจริง (Boolean) จึงมีชนิดข้อมูลเป็น bool และการใช้ตัวดำเนินการ and จะให้ค่า True ก็ต่อเมื่อทั้งสองค่ามีค่าเป็น True

# %%
# Puzzler 4
# What happens here?
# num_str = input("Enter a number: ")
# result = num_str + 5
# print(result)

# %% [markdown]
# โปรแกรมจะเกิดข้อผิดพลาด เนื่องจาก input() รับข้อมูลเป็นชนิด string เสมอ จึงไม่สามารถนำมาบวกกับจำนวนเต็ม (int) ได้ หากต้องการคำนวณต้องแปลงข้อมูลก่อน
